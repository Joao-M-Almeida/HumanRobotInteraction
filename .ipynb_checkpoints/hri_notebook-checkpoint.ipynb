# %%
import pandas as pd
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn import preprocessing
import numpy as np
import time
from sklearn.metrics import accuracy_score
from sklearn import cross_validation
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import confusion_matrix

# %%
def time_transform(x):
    if x >= 1000:
        x=0

# %%
database.groupby("g5").size()
# Out:
# g5
# 0     364
# 1      80
# 2      92
# 3     144
# 4      10
# 5     196
# 6      55
# 7      44
# 8     305
# 9      55
# 10     70
# 11     46
# 12     67
# 13    190
# 14     34
# 15     49
# 16     19
# dtype: int64

# %%
database.describe()
# Out:
#                 dx    dy           g1    t1          vx1   vy1           g2  \
# count  1820.000000  1820  1820.000000  1820  1820.000000  1820  1820.000000
# mean      2.343752     0     7.730220     0     0.186537     0     7.342308
# std       0.892665     0     4.035204     0     0.734500     0     4.317762
# min       0.000000     0     1.000000     0    -2.700677     0     0.000000
# 25%       1.632121     0     5.000000     0    -0.021213     0     3.000000
# 50%       1.980591     0     8.000000     0    -0.000209     0     8.000000
# 75%       2.871147     0    11.000000     0     0.020388     0    11.000000
# max       4.502469     0    16.000000     0     4.413043     0    16.000000
#
#          t2          vx2   vy2  ...           vx3   vy3           g4    t4  \
# count  1820  1820.000000  1820  ...   1820.000000  1820  1820.000000  1820
# mean      0     0.187368     0  ...      0.183327     0     6.571429     0
# std       0     0.731028     0  ...      0.724893     0     4.671726     0
# min       0    -2.700677     0  ...     -2.700677     0     0.000000     0
# 25%       0    -0.018580     0  ...     -0.014960     0     2.000000     0
# 50%       0    -0.000048     0  ...      0.000000     0     7.000000     0
# 75%       0     0.017007     0  ...      0.013328     0    10.000000     0
# max       0     4.413043     0  ...      4.413043     0    16.000000     0
#
#                vx4   vy4           g5    t5          vx5   vy5
# count  1820.000000  1820  1820.000000  1820  1820.000000  1820
# mean      0.179910     0     6.200000     0     0.176263     0
# std       0.719756     0     4.795499     0     0.711420     0
# min      -2.700677     0     0.000000     0    -2.700677     0
# 25%      -0.011314     0     2.000000     0    -0.010198     0
# 50%       0.000000     0     6.000000     0     0.000000     0
# 75%       0.010845     0    10.000000     0     0.007419     0
# max       4.413043     0    16.000000     0     4.413043     0
#
# [8 rows x 22 columns]

# %%
database = pd.read_csv("/home/jmirandadealme/Documents/SistAut/HumanRobotInteraction/others/TrainingData/todos.txt",
                      quotechar ="'")



#database["t5"] = 0
#database["t4"] = 0
#database["t3"] = 0
#database["t2"] = 0
#database["t1"] = 0




le = preprocessing.LabelEncoder()
le.fit(['0.0','closingforearm','armmovingdown','armmovingup',
        'armstopped','forearmstopped','handaboveelbow','handunderelbow',
        'openingforearm','walkingbackward','walkingforward','waving','nowalking',
        'calling', 'handing','elbowbehindbody','elbowinfrontofbody'])
database["g1"]=le.transform(database["g1"])
database["g2"]=le.transform(database["g2"])
database["g3"]=le.transform(database["g3"])
database["g4"]=le.transform(database["g4"])
database["g5"]=le.transform(database["g5"])

labels = database['label'].values

database.drop("label",axis=1,inplace=True)

database.head()
# Out:
#          dx  dy  g1            t1       vx1  vy1  g2            t2       vx2  \
# 0  4.404114   0   1  1.448972e+09  4.404114    0   0  1.448972e+09  0.000000
# 1  4.404114   0   5  1.448972e+09  4.404114    0   1  0.000000e+00  4.404114
# 2  4.392251   0   3  1.448972e+09 -0.011864    0   5  1.000001e-01  4.404114
# 3  4.392251   0   8  1.448972e+09 -0.011864    0   3  0.000000e+00 -0.011864
# 4  4.364057   0  13  1.448972e+09 -0.028194    0   8  2.000000e-01 -0.011864
#
#    vy2 ...        vx3  vy3  g4            t4       vx4  vy4  g5            t5  \
# 0    0 ...   0.000000    0   0 -1.448972e+09  0.000000    0   0 -1.448972e+09
# 1    0 ...   0.000000    0   0 -1.448972e+09  0.000000    0   0 -1.448972e+09
# 2    0 ...   4.404114    0   0  1.448972e+09  0.000000    0   0 -1.448972e+09
# 3    0 ...   4.404114    0   1 -1.000001e-01  4.404114    0   0  1.448972e+09
# 4    0 ...  -0.011864    0   5 -9.999990e-02  4.404114    0   1 -3.000002e-01
#
#         vx5  vy5
# 0  0.000000    0
# 1  0.000000    0
# 2  0.000000    0
# 3  0.000000    0
# 4  4.404114    0
#
# [5 rows x 22 columns]

# %%
database = pd.read_csv("/home/jmirandadealme/Documents/SistAut/HumanRobotInteraction/others/TrainingData/todos2.txt",
                      quotechar ="'")



labels = database['label'].values

database.drop("label",axis=1,inplace=True)

database.head()
features = database.values
# Out:
#        dx  dy  g1  t1       vx1  vy1  g2   t2       vx2  vy2 ...        vx3  \
# 0  4.4041   0   6   0  4.404100    0   0  0.0  0.000000    0 ...   0.000000
# 1  4.4041   0   1   0  4.404100    0   6  0.0  4.404100    0 ...   0.000000
# 2  4.3923   0   5   0 -0.011864    0   1  0.1  4.404100    0 ...   4.404100
# 3  4.3923   0   4   0 -0.011864    0   5  0.0 -0.011864    0 ...   4.404100
# 4  4.3641   0   7   0 -0.028194    0   4  0.2 -0.011864    0 ...  -0.011864
#
#    vy3  g4   t4     vx4  vy4  g5   t5     vx5  vy5
# 0    0   0  0.0  0.0000    0   0  0.0  0.0000    0
# 1    0   0  0.0  0.0000    0   0  0.0  0.0000    0
# 2    0   0  0.0  0.0000    0   0  0.0  0.0000    0
# 3    0   6 -0.1  4.4041    0   0  0.0  0.0000    0
# 4    0   1 -0.1  4.4041    0   6 -0.3  4.4041    0
#
# [5 rows x 22 columns]

# %%
features = database.values

pca = PCA(n_components =15)
pca.fit(features)
features = pca.transform(features)
print(pca.explained_variance_ratio_)
# Out:
# [  4.06145763e-01   1.81421173e-01   1.48853239e-01   1.26536724e-01
#    1.00589097e-01   8.29989775e-03   6.64419059e-03   4.49727962e-03
#    4.40387766e-03   3.87524331e-03   3.35531363e-03   2.29484179e-03
#    1.59392518e-03   1.24826668e-03   2.41167869e-04]

# %%
# TRAIN SVM


classf = SVC()
start_time = time.time()
classf.fit(features,labels)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.992444992065 seconds ---

# %%
# TRAIN LinearSVC


classf = LinearSVC()
start_time = time.time()
classf.fit(features,labels)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.801818847656 seconds ---

# %%
# TRAIN LogisticRegression

classf = LogisticRegression()
start_time = time.time()
classf.fit(features,labels)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.0455949306488 seconds ---

# %%
# TRAIN 3NN

classf = KNeighborsClassifier(n_neighbors=5)
start_time = time.time()
classf.fit(features,labels)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.00180292129517 seconds ---

# %%
# TRAIN AdaBoostClassifier

classf = AdaBoostClassifier()
start_time = time.time()
classf.fit(features,labels)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.232806921005 seconds ---

# %%
# Train SGDClassifier

classf = SGDClassifier()
start_time = time.time()
classf.fit(features,labels)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.00567102432251 seconds ---

# %%
# Predict

start_time = time.time()
predict_labels=classf.predict(features)
print("--- %s seconds ---" % (time.time() - start_time))
score = accuracy_score(labels,predict_labels)
print("Accuracy: %0.2f" % (score))
# Cross Validation
start_time = time.time()
scores = cross_validation.cross_val_score(classf, features, labels, cv=10)
print("--- %s seconds ---" % (time.time() - start_time))
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# --- 0.194025039673 seconds ---
# Accuracy: 0.84
# --- 3.02102398872 seconds ---
# Accuracy: 0.65 (+/- 0.13)

# %%
# Predict 

start_time = time.time()
predict_labels=classf.predict(features)
print("--- %s seconds ---" % (time.time() - start_time))
score = accuracy_score(labels,predict_labels)
print("Accuracy: %0.2f" % (score))

cm = confusion_matrix(labels, predict_labels)
print('Confusion matrix, without normalization')
print(cm)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
print('Normalized confusion matrix')
print(cm_normalized)
# Out:
# --- 0.196441173553 seconds ---
# Accuracy: 0.84
# Confusion matrix, without normalization
# [[346  34   0  15   0   2   0]
#  [  4 257   2  20   0   6   0]
#  [ 17  14 105  31   2   8   0]
#  [  0  11   0 328   0   6   0]
#  [ 14   1   0   1 395   0   0]
#  [  8   6   2  28   1  60   1]
#  [ 12  11   2  19   9   4  38]]
# Normalized confusion matrix
# [[ 0.87153652  0.08564232  0.          0.03778338  0.          0.00503778
#    0.        ]
#  [ 0.01384083  0.88927336  0.00692042  0.06920415  0.          0.02076125
#    0.        ]
#  [ 0.0960452   0.07909605  0.59322034  0.17514124  0.01129944  0.04519774
#    0.        ]
#  [ 0.          0.03188406  0.          0.95072464  0.          0.0173913
#    0.        ]
#  [ 0.03406326  0.00243309  0.          0.00243309  0.96107056  0.          0.        ]
#  [ 0.0754717   0.05660377  0.01886792  0.26415094  0.00943396  0.56603774
#    0.00943396]
#  [ 0.12631579  0.11578947  0.02105263  0.2         0.09473684  0.04210526
#    0.4       ]]

# %%
# Predict 

start_time = time.time()
predict_labels=classf.predict(features)
print("--- %s seconds ---" % (time.time() - start_time))
score = accuracy_score(labels,predict_labels)
print("Accuracy: %0.2f" % (score))

cm = confusion_matrix(labels, predict_labels)
print('Confusion matrix, without normalization')
print(cm)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
print('Normalized confusion matrix')
print(cm_normalized)
# Out:
# --- 0.486978054047 seconds ---
# Accuracy: 0.76
# Confusion matrix, without normalization
# [[913  32   1  16  23   2   0]
#  [ 24 269   5  21   0   6   2]
#  [ 64  24 201  42   3   7   0]
#  [ 14  14   7 325   0   6   0]
#  [116   2   3   2 390   0   1]
#  [ 28   8  10  22   0  52   1]
#  [120  15   7  24  16   4  61]]
# Normalized confusion matrix
# [[ 0.92502533  0.03242148  0.00101317  0.01621074  0.02330294  0.00202634
#    0.        ]
#  [ 0.0733945   0.82262997  0.01529052  0.06422018  0.          0.01834862
#    0.00611621]
#  [ 0.18768328  0.07038123  0.58944282  0.12316716  0.00879765  0.02052786
#    0.        ]
#  [ 0.03825137  0.03825137  0.01912568  0.88797814  0.          0.01639344
#    0.        ]
#  [ 0.22568093  0.00389105  0.00583658  0.00389105  0.75875486  0.
#    0.00194553]
#  [ 0.23140496  0.0661157   0.08264463  0.18181818  0.          0.42975207
#    0.00826446]
#  [ 0.48582996  0.06072874  0.02834008  0.09716599  0.06477733  0.01619433
#    0.24696356]]

# %%
database = pd.read_csv("/home/jmirandadealme/Documents/SistAut/HumanRobotInteraction/others/TrainingData/TUDO.csv",
                      quotechar ="'")



labels = database['label'].values

database.drop("label",axis=1,inplace=True)
features = database.values
database.describe()
# Out:
#                 dx    dy           g1    t1          vx1   vy1           g2  \
# count  2903.000000  2903  2903.000000  2903  2903.000000  2903  2903.000000
# mean      2.459664     0     7.246986     0     0.118047     0     7.017913
# std       0.909026     0     4.767073     0     0.597448     0     4.870447
# min       0.000000     0     1.000000     0    -2.700700     0     0.000000
# 25%       1.676300     0     4.000000     0    -0.024510     0     3.000000
# 50%       2.088300     0     5.000000     0    -0.000003     0     5.000000
# 75%       3.304200     0    12.000000     0     0.030694     0    11.000000
# max       4.502500     0    16.000000     0     4.413000     0    16.000000
#
#                 t2          vx2   vy2  ...           vx3   vy3           g4  \
# count  2903.000000  2903.000000  2903  ...   2903.000000  2903  2903.000000
# mean      0.186288     0.118618     0  ...      0.116124     0     6.564588
# std       0.507087     0.594817     0  ...      0.589788     0     5.027411
# min       0.000000    -2.700700     0  ...     -2.700700     0     0.000000
# 25%       0.000000    -0.022834     0  ...     -0.022083     0     2.000000
# 50%       0.099000     0.000000     0  ...      0.000000     0     5.000000
# 75%       0.199000     0.029254     0  ...      0.028456     0    10.000000
# max      13.303000     4.413000     0  ...      4.413000     0    16.000000
#
#                 t4          vx4   vy4           g5           t5          vx5  \
# count  2903.000000  2903.000000  2903  2903.000000  2903.000000  2903.000000
# mean     -0.169532     0.114022     0     6.356183    -0.331229     0.111776
# std       0.802359     0.585576     0     5.100901     0.932822     0.578886
# min     -13.401000    -2.700700     0     0.000000   -13.907000    -2.700700
# 25%      -0.204000    -0.020642     0     2.000000    -0.400000    -0.018092
# 50%      -0.098000     0.000000     0     5.000000    -0.198000     0.000000
# 75%       0.000000     0.025856     0    10.000000     0.000000     0.022545
# max      12.601000     4.413000     0    16.000000    11.803000     4.413000
#
#         vy5
# count  2903
# mean      0
# std       0
# min       0
# 25%       0
# 50%       0
# 75%       0
# max       0
#
# [8 rows x 22 columns]
